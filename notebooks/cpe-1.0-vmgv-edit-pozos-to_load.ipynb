# %%
# Importamos las librerias a utilizar
import pandas as pd
import numpy as np
import sys
import os

# Definimos las rutas de los archivos a emplear
notebook_dir = os.getcwd()
scripts_dir = os.path.join(notebook_dir, "..", "src")
sys.path.append(scripts_dir)

# Funciones importadas como modulos
from data_transform.load_csv import load_csv
from data_transform.map_cimas_to_depth_multiple import map_cimas_create_columns
from data_transform.map_intervalos import generar_intervalos_disparados

# Codigo para imprimir mas de una salida de la misma celda
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Definimos las rutas de los registros de pozo y cimas 
logs_file_name = "logs_pijije_rhob_nphi_dtco_syn.csv"
path_well_logs = os.path.join(notebook_dir, "..", "data", "raw", logs_file_name)

# Cargamos la informacion de los pozos
well_logs_df = load_csv(path_well_logs)

# Verificamos que no exista ninguna valor negativo en md
well_logs_df = well_logs_df[well_logs_df["md"] >= 0]

# %%
well_logs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 658469 entries, 0 to 658476
# Data columns (total 24 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   wellname   658469 non-null  object
#  1   md         658469 non-null  float64
#  2   bs         38067 non-null   float64
#  3   cal        199906 non-null  float64
#  4   cgr        47902 non-null   float64
#  5   cgr_f      1765 non-null    float64
#  6   cgr_sint   44838 non-null   float64
#  7   dtco       268729 non-null  float64
#  8   dtsm       61577 non-null   float64
#  9   gr         523032 non-null  float64
#  10  gr_norm    1839 non-null    float64
#  11  gr_norm_f  24249 non-null   float64
#  12  nphi       213854 non-null  float64
#  13  pef        151068 non-null  float64
#  14  pota       17559 non-null   float64
#  15  rhob       89506 non-null   float64
#  16  rhob_norm  1833 non-null    float64
#  17  rm         257661 non-null  float64
#  18  rp         599367 non-null  float64
#  19  rs         257989 non-null  float64
#  20  spn        7011 non-null    float64
#  21  thor       17559 non-null   float64
#  22  ura        12314 non-null   float64
#  23  uran       5267 non-null    float64
# dtypes: float64(23), object(1)
# memory usage: 125.6+ MB

# %%
well_logs_df.head(20)
# Out:
#         wellname          md  bs  cal  cgr  cgr_f  cgr_sint  dtco  dtsm  gr  \
# 0   Caparroso-71  499.903015 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 1   Caparroso-71  500.055420 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 2   Caparroso-71  500.207825 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 3   Caparroso-71  500.360229 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 4   Caparroso-71  500.512604 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 5   Caparroso-71  500.665009 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 6   Caparroso-71  500.817413 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 7   Caparroso-71  500.969818 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 8   Caparroso-71  501.122223 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 9   Caparroso-71  501.274628 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 10  Caparroso-71  501.427002 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 11  Caparroso-71  501.579407 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 12  Caparroso-71  501.731812 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 13  Caparroso-71  501.884216 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 14  Caparroso-71  502.036621 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 15  Caparroso-71  502.189026 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 16  Caparroso-71  502.341400 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 17  Caparroso-71  502.493805 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 18  Caparroso-71  502.646210 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
# 19  Caparroso-71  502.798615 NaN  NaN  NaN    NaN       NaN   NaN   NaN NaN
#
#     ...  pota  rhob  rhob_norm  rm        rp  rs  spn  thor  ura  uran
# 0   ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 1   ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 2   ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 3   ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 4   ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 5   ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 6   ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 7   ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 8   ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 9   ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 10  ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 11  ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 12  ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 13  ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 14  ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 15  ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 16  ...   NaN   NaN        NaN NaN       NaN NaN  NaN   NaN  NaN   NaN
# 17  ...   NaN   NaN        NaN NaN  0.834395 NaN  NaN   NaN  NaN   NaN
# 18  ...   NaN   NaN        NaN NaN  0.805148 NaN  NaN   NaN  NaN   NaN
# 19  ...   NaN   NaN        NaN NaN  0.877251 NaN  NaN   NaN  NaN   NaN
#
# [20 rows x 24 columns]
